# %%
#Don't forget to change runtime to T4 GPU
# Out:
# Requirement already satisfied: nvcc4jupyter in /usr/local/lib/python3.12/dist-packages (1.2.1)

# %%
# !pip install nvcc4jupyter

# %%
# !nvidia-smi
# Out:
# Thu May 14 06:35:18 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %load_ext nvcc4jupyter
# Out:
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmpf44jvl3v".

# %%
# %%cuda
# #include <iostream>
#
# __global__ void helloFromGPU() {
#     printf("Hello World from GPU!\n");
# }
#
# int main() {
#     helloFromGPU<<<1, 1>>>();
#     cudaDeviceSynchronize();
#     return 0;
# }
# Out:
# Hello World from GPU!

# %%
# %%cuda
# #include <stdio.h>
#
# __global__ void hello() {
#     printf("Hello from GPU thread %d\n", threadIdx.x);
# }
#
# int main() {
#     hello<<<1, 10>>>();      // 1 block, 10 threads
#     cudaDeviceSynchronize(); // wait for the GPU to finish
#     return 0;
# }
# Out:
# Hello from GPU thread 0
# Hello from GPU thread 1
# Hello from GPU thread 2
# Hello from GPU thread 3
# Hello from GPU thread 4
# Hello from GPU thread 5
# Hello from GPU thread 6
# Hello from GPU thread 7
# Hello from GPU thread 8
# Hello from GPU thread 9
